# %%
#Welcome back!

# %% [markdown]
# # Welcome Back!

# %% [markdown]
# # Welcome [Nathaniel](mailto:ndporter@vt.edu)

# %%
#import pandas (pd is shortcut)
import pandas as pd

# %%
#download southern focus poll in Excel format
indata = pd.read_excel('http://www.thearda.com/download/download.aspx?file=Southern%20Focus%20Poll,%20South%20Survey,%20Spring%202001.XLS')
# Out:
# WARNING *** file size (2011287) not 512 + multiple of sector size (512)
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
# *** No CODEPAGE record, no encoding_override: will use 'ascii'

# %%
indata
# Out:
#      CaseID$  RESP  STATE  YRBORN  COMSOUTH  LIVESOU  TRAVOUT  STATE16  \
# 0        119  3155     34    1978         1      1.0      NaN       36
# 1        120  1341     34    1958         1      3.0      NaN       15
# 2        121  2123     37    1949         1      3.0      NaN       13
# 3        122  3219     37    1947         1      3.0      NaN       26
# 4        123  2452     41    1928         1      3.0      NaN       41
# 5        124  3363     41    1945         1      4.0      1.0       41
# 6        125  1796     41    1958         1      3.0      NaN       34
# 7        126  3124     43    1963         1      4.0      2.0       43
# 8        127  1830     43    1948         1      4.0      1.0       43
# 9        128  1229     43    1969         1      4.0      2.0       43
# 10       129  3498     43    1945         1      3.0      NaN       50
# 11       130  2510     43    1967         1      3.0      NaN       43
# ...

# %%
indata.head()
# Out:
#    CaseID$  RESP  STATE  YRBORN  COMSOUTH  LIVESOU  TRAVOUT  STATE16  \
# 0      119  3155     34    1978         1      1.0      NaN       36
# 1      120  1341     34    1958         1      3.0      NaN       15
# 2      121  2123     37    1949         1      3.0      NaN       13
# 3      122  3219     37    1947         1      3.0      NaN       26
# 4      123  2452     41    1928         1      3.0      NaN       41
#
#    LIVSTAT1  LIVSTAT2   ...    OTHRACE2  IAM12  IAM22  IAM32  I-AGE  I-EDUC  \
# 0       NaN       1.0   ...         NaN    NaN    NaN    NaN    0.0     1.0
# 1       NaN       4.0   ...         NaN  165.0   96.0  126.0    1.0     4.0
# 2       NaN       4.0   ...         NaN    NaN    NaN    NaN    2.0     2.0
# 3       NaN       1.0   ...         NaN  174.0  175.0  398.0    2.0     4.0
# 4       5.0       NaN   ...         NaN    NaN    NaN    NaN    3.0     3.0
#
#    I-GENDER  I-INCOME  I-MARITAL  I-RACE
# 0         1       2.0        1.0     1.0
# ...

# %%
odds = [1,3,5,7]

# %%
odds
# Out:
# [1, 3, 5, 7]

# %%
odds[2]
# Out:
# 5

# %%
indata['YRBORN']
# Out:
# 0      1978
# 1      1958
# 2      1949
# 3      1947
# 4      1928
# 5      1945
# 6      1958
# 7      1963
# 8      1948
# 9      1969
# 10     1945
# 11     1967
# 12     1974
# 13     1973
# 14     1977
# 15     1953
# 16     1966
# 17     1979
# 18     1981
# 19     1975
# 20     1934
# 21     1933
# 22     1977
# 23     1942
# 24     1966
# 25     1968
# 26     1973
# 27     1950
# 28     1921
# 29     1980
#        ...
# 822    1931
# 823    1982
# 824    1956
# 825    1982
# 826    1969
# 827    1935
# 828    1981
# 829    1960
# 830    1955
# 831    1980
# 832    1980
# 833    1964
# 834    1964
# 835    1971
# 836    1944
# 837    1979
# 838    1961
# 839    1976
# 840    1972
# 841    1981
# 842    1940
# 843    1937
# 844    1972
# 845    1943
# 846    1977
# 847    1955
# 848    1973
# 849    1891
# 850    1928
# 851    1930
# Name: YRBORN, Length: 852, dtype: int64

# %%
indata['YRBORN'].head()
# Out:
# 0    1978
# 1    1958
# 2    1949
# 3    1947
# 4    1928
# Name: YRBORN, dtype: int64

# %%
indata['YRBORN'].describe()
# Out:
# count     852.000000
# mean     1955.599765
# std        18.770383
# min      1891.000000
# 25%      1945.000000
# 50%      1958.000000
# 75%      1971.000000
# max      1983.000000
# Name: YRBORN, dtype: float64

# %%
#loc allows reference by name
print(indata.loc[9,'YRBORN'])
# Out:
# 1969

# %%
print(indata.iloc[9,3])
# Out:
# 1969

# %%
#slicing
print(indata.iloc[9,-5:-1])
# Out:
# I-EDUC       1
# I-GENDER     2
# I-INCOME     1
# I-MARITAL    1
# Name: 9, dtype: object

# %%
print(indata.iloc[9,:])
# Out:
# CaseID$           128
# RESP             1229
# STATE              43
# YRBORN           1969
# COMSOUTH            1
# LIVESOU             4
# TRAVOUT             2
# STATE16            43
# LIVSTAT1            6
# LIVSTAT2          NaN
# SOUTHERN            1
# SIDIMP              4
# SGLOBL1           NaN
# SGLOBL2             1
# ZIPCODE         38112
# LIVEWH              1
# GENDER              2
# EDUC               12
# RELIG               3
# RELIGIMP            1
# RELAFFL             1
# NORELIG           NaN
# RELAFCHK            1
# DMETHDST          NaN
# DPRESBY           NaN
# DLUTHRAN          NaN
# DDISCIPL          NaN
# DCHRIST           NaN
# DCHGOD            NaN
# DHOLINES          NaN
#                ...
# STATEFPS           47
# ST_CNTY         47157
# FAITH97X            1
# FAITH               1
# SGLOBL              2
# SGLOBQ              2
# AGEMARR           NaN
# AGEMCAT           NaN
# MAWOCAT             5
# MAMNCAT             5
# ...

# %%
#what if we only want people who say they're living in the south?
indata.head()
# Out:
#    CaseID$  RESP  STATE  YRBORN  COMSOUTH  LIVESOU  TRAVOUT  STATE16  \
# 0      119  3155     34    1978         1      1.0      NaN       36
# 1      120  1341     34    1958         1      3.0      NaN       15
# 2      121  2123     37    1949         1      3.0      NaN       13
# 3      122  3219     37    1947         1      3.0      NaN       26
# 4      123  2452     41    1928         1      3.0      NaN       41
#
#    LIVSTAT1  LIVSTAT2   ...    OTHRACE2  IAM12  IAM22  IAM32  I-AGE  I-EDUC  \
# 0       NaN       1.0   ...         NaN    NaN    NaN    NaN    0.0     1.0
# 1       NaN       4.0   ...         NaN  165.0   96.0  126.0    1.0     4.0
# 2       NaN       4.0   ...         NaN    NaN    NaN    NaN    2.0     2.0
# 3       NaN       1.0   ...         NaN  174.0  175.0  398.0    2.0     4.0
# 4       5.0       NaN   ...         NaN    NaN    NaN    NaN    3.0     3.0
#
#    I-GENDER  I-INCOME  I-MARITAL  I-RACE
# 0         1       2.0        1.0     1.0
# ...

# %%
southerners = indata[indata['COMSOUTH']==1]
southerners.head()
# Out:
#    CaseID$  RESP  STATE  YRBORN  COMSOUTH  LIVESOU  TRAVOUT  STATE16  \
# 0      119  3155     34    1978         1      1.0      NaN       36
# 1      120  1341     34    1958         1      3.0      NaN       15
# 2      121  2123     37    1949         1      3.0      NaN       13
# 3      122  3219     37    1947         1      3.0      NaN       26
# 4      123  2452     41    1928         1      3.0      NaN       41
#
#    LIVSTAT1  LIVSTAT2   ...    OTHRACE2  IAM12  IAM22  IAM32  I-AGE  I-EDUC  \
# 0       NaN       1.0   ...         NaN    NaN    NaN    NaN    0.0     1.0
# 1       NaN       4.0   ...         NaN  165.0   96.0  126.0    1.0     4.0
# 2       NaN       4.0   ...         NaN    NaN    NaN    NaN    2.0     2.0
# 3       NaN       1.0   ...         NaN  174.0  175.0  398.0    2.0     4.0
# 4       5.0       NaN   ...         NaN    NaN    NaN    NaN    3.0     3.0
#
#    I-GENDER  I-INCOME  I-MARITAL  I-RACE
# 0         1       2.0        1.0     1.0
# ...

# %%
southerners
# Out:
#      CaseID$  RESP  STATE  YRBORN  COMSOUTH  LIVESOU  TRAVOUT  STATE16  \
# 0        119  3155     34    1978         1      1.0      NaN       36
# 1        120  1341     34    1958         1      3.0      NaN       15
# 2        121  2123     37    1949         1      3.0      NaN       13
# 3        122  3219     37    1947         1      3.0      NaN       26
# 4        123  2452     41    1928         1      3.0      NaN       41
# 5        124  3363     41    1945         1      4.0      1.0       41
# 6        125  1796     41    1958         1      3.0      NaN       34
# 7        126  3124     43    1963         1      4.0      2.0       43
# 8        127  1830     43    1948         1      4.0      1.0       43
# 9        128  1229     43    1969         1      4.0      2.0       43
# 10       129  3498     43    1945         1      3.0      NaN       50
# 11       130  2510     43    1967         1      3.0      NaN       43
# ...

# %%
valid = southerners.dropna(subset=['TRAVOUT'])
valid.head()
# Out:
#     CaseID$  RESP  STATE  YRBORN  COMSOUTH  LIVESOU  TRAVOUT  STATE16  \
# 5       124  3363     41    1945         1      4.0      1.0       41
# 7       126  3124     43    1963         1      4.0      2.0       43
# 8       127  1830     43    1948         1      4.0      1.0       43
# 9       128  1229     43    1969         1      4.0      2.0       43
# 12      131  1237     44    1974         1      4.0      2.0       44
#
#     LIVSTAT1  LIVSTAT2   ...    OTHRACE2  IAM12  IAM22  IAM32  I-AGE  I-EDUC  \
# 5        6.0       NaN   ...         NaN  180.0   77.0  267.0    2.0     1.0
# 7        6.0       NaN   ...         NaN  337.0  398.0    NaN    0.0     0.0
# 8        6.0       NaN   ...         NaN   27.0  323.0  194.0    2.0     2.0
# 9        6.0       NaN   ...         NaN   20.0    NaN    NaN    0.0     1.0
# 12       6.0       NaN   ...         NaN  180.0  397.0  342.0    0.0     1.0
#
#     I-GENDER  I-INCOME  I-MARITAL  I-RACE
# ...

# %%
valid['TRAVOUT'].value_counts()
# Out:
# 1.0    441
# 2.0     61
# Name: TRAVOUT, dtype: int64

# %%
valid['TRAVOUT'].value_counts(normalize=True)
# Out:
# 1.0    0.878486
# 2.0    0.121514
# Name: TRAVOUT, dtype: float64

# %%
# %matplotlib inline

# %%
valid['YRBORN'].hist(by=valid['TRAVOUT'])
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F7C2145908>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000001F7C3632EF0>], dtype=object)
